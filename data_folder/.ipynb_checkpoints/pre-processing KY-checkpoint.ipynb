# %%
import geopandas as gp
import csv
import pandas as pd
from shapely.geometry import LineString
import matplotlib.pyplot as plot
import mysql.connector
from shapely.geometry import Polygon, mapping
import datetime

# %%
file = "../data/old/ky_p.geojson"    

df = gp.read_file(file)
df.head()
# Out:
#    republican   area        vtd vtdid          name state_coun  population  \
# 0        0.45  13.08  21117B123  B123         Piner      21117        1167
# 1        0.48  12.56  21117B121  B121  Nicholson #2      21117        2432
# 2         NaN   1.55  21117X001  X001          X001      21117           0
# 3        0.25  26.95  21149C101  C101    Calhoun #1      21149        1247
# 4        0.32  19.35  21149C102  C102  Livermore #2      21149        1194
#
#    democrats  democrat_p  republic_1  ...  male  male_perce  female  \
# 0        351        0.43         371  ...   404        0.35     420
# 1        712        0.41         834  ...   851        0.35     893
# 2          0         NaN           0  ...     0         NaN       0
# 3        586        0.71         207  ...   389        0.31     439
# 4        531        0.62         276  ...   412        0.35     438
#
#    female_per  total_regi  registered       id  data  dem_rep_di  \
# 0        0.36         824        0.71  4470011  2243       -0.02
# 1        0.37        1744        0.72  4470064  2241       -0.07
# 2         NaN           0         NaN  4521696  2296         NaN
# 3        0.35         828        0.66        0     0        0.46
# 4        0.37         850        0.71        0     0        0.30
#
#                                             geometry
# 0  MULTIPOLYGON (((-84.50452 38.79535, -84.51877 ...
# 1  MULTIPOLYGON (((-84.53611 38.85136, -84.53592 ...
# 2  MULTIPOLYGON (((-84.54152 39.09927, -84.52563 ...
# 3  MULTIPOLYGON (((-87.14360 37.57777, -87.13882 ...
# 4  MULTIPOLYGON (((-87.15110 37.49865, -87.15485 ...
#
# [5 rows x 23 columns]

# %%
reader = csv.reader(open('../data/KY_county.csv', 'r'))
d = {}
for row in reader:
    #id = row['County FIPS']
    key = row[0]
    value = row[1]
    d[key] = value
#print (d)

# %%
#Rename columns
df = df.drop (columns = ['republican', 'name', 'population', 'democrats', 'democrat_p','republic_1',
                        'cartodb_id', 'other', 'other_perc', 'male', 'male_perce', 'female',
                         'female_per', 'total_regi', 'registered', 'id', 'data', 'dem_rep_di'])

df.rename(columns = {"vtd":"id"}, inplace = True)
df.rename(columns = {"vtdid":"canonical"}, inplace = True)
#df.rename(columns = {"INTPTLAT10":"centerX"}, inplace = True)
#df.rename(columns = {"INTPTLON10":"centerY"}, inplace = True)

#Add type columns
df.insert(2, 'type', 'ORIGINAL')
df.insert(3, 'centerX', None)
df.insert(4, 'centerY', None)
#df.insert(5, 'area', None)

#df = df.drop ()
df.head()
# Out:
#     area         id      type centerX centerY canonical state_coun  \
# 0  13.08  21117B123  ORIGINAL    None    None      B123      21117
# 1  12.56  21117B121  ORIGINAL    None    None      B121      21117
# 2   1.55  21117X001  ORIGINAL    None    None      X001      21117
# 3  26.95  21149C101  ORIGINAL    None    None      C101      21149
# 4  19.35  21149C102  ORIGINAL    None    None      C102      21149
#
#                                             geometry
# 0  MULTIPOLYGON (((-84.50452 38.79535, -84.51877 ...
# 1  MULTIPOLYGON (((-84.53611 38.85136, -84.53592 ...
# 2  MULTIPOLYGON (((-84.54152 39.09927, -84.52563 ...
# 3  MULTIPOLYGON (((-87.14360 37.57777, -87.13882 ...
# 4  MULTIPOLYGON (((-87.15110 37.49865, -87.15485 ...

# %%
#Canonical name
state = 'KY'
for i, row in df.iterrows():   
    id = df.at[i, 'canonical']
    countyId = df.at[i, 'state_coun']
    #print (countyId)
    canonicalId = state + ' ' + d[countyId] + ' ' + id
    df.at[i, 'canonical'] = canonicalId
    
    #print (canonicalId)


#Drop column

df.head()
#df.head()
# Out:
#     area         id      type centerX centerY       canonical state_coun  \
# 0  13.08  21117B123  ORIGINAL    None    None  KY Kenton B123      21117
# 1  12.56  21117B121  ORIGINAL    None    None  KY Kenton B121      21117
# 2   1.55  21117X001  ORIGINAL    None    None  KY Kenton X001      21117
# 3  26.95  21149C101  ORIGINAL    None    None  KY McLean C101      21149
# 4  19.35  21149C102  ORIGINAL    None    None  KY McLean C102      21149
#
#                                             geometry
# 0  MULTIPOLYGON (((-84.50452 38.79535, -84.51877 ...
# 1  MULTIPOLYGON (((-84.53611 38.85136, -84.53592 ...
# 2  MULTIPOLYGON (((-84.54152 39.09927, -84.52563 ...
# 3  MULTIPOLYGON (((-87.14360 37.57777, -87.13882 ...
# 4  MULTIPOLYGON (((-87.15110 37.49865, -87.15485 ...

# %%
#Replace multipoly with polygon
arr_polygon = [0] * len(df)
arr_polygon = gp.GeoDataFrame (arr_polygon, columns = ['geometry'])
for index, row in df.iterrows():
    #Progress
    if index % 1000 == 0:
        print (index, datetime.datetime.now())
    polygon = row.geometry[0]
    arr_polygon.loc[index] = polygon
    
df['geometry'] = arr_polygon
df.head()
# Out:
# 0 2020-04-12 21:38:04.632652
# 1000 2020-04-12 21:38:04.833698
# 2000 2020-04-12 21:38:05.017739
# 3000 2020-04-12 21:38:05.204781
#     area         id      type centerX centerY       canonical state_coun  \
# 0  13.08  21117B123  ORIGINAL    None    None  KY Kenton B123      21117
# 1  12.56  21117B121  ORIGINAL    None    None  KY Kenton B121      21117
# 2   1.55  21117X001  ORIGINAL    None    None  KY Kenton X001      21117
# 3  26.95  21149C101  ORIGINAL    None    None  KY McLean C101      21149
# 4  19.35  21149C102  ORIGINAL    None    None  KY McLean C102      21149
#
#                                             geometry
# 0  POLYGON ((-84.50452 38.79535, -84.51877 38.793...
# 1  POLYGON ((-84.53611 38.85136, -84.53592 38.858...
# 2  POLYGON ((-84.54152 39.09927, -84.52563 39.092...
# 3  POLYGON ((-87.14360 37.57777, -87.13882 37.575...
# 4  POLYGON ((-87.15110 37.49865, -87.15485 37.500...

# %%
#ADD area and centers
for i, row in df.iterrows():
    #df.at[i, 'area'] = row.geometry.area
    bounds = row.geometry.bounds
    centerX = (bounds[0] + bounds[2]) / 2
    centerY = (bounds[1] + bounds[3]) / 2
    df.at[i, 'centerX'] = centerX
    df.at[i, 'centerY'] = centerY

# %%
df.head()
# Out:
#     area         id      type  centerX  centerY       canonical state_coun  \
# 0  13.08  21117B123  ORIGINAL -84.5233   38.825  KY Kenton B123      21117
# 1  12.56  21117B121  ORIGINAL -84.5277  38.8932  KY Kenton B121      21117
# 2   1.55  21117X001  ORIGINAL -84.5635  39.0853  KY Kenton X001      21117
# 3  26.95  21149C101  ORIGINAL -87.1876  37.5516  KY McLean C101      21149
# 4  19.35  21149C102  ORIGINAL  -87.102  37.5327  KY McLean C102      21149
#
#                                             geometry
# 0  POLYGON ((-84.50452 38.79535, -84.51877 38.793...
# 1  POLYGON ((-84.53611 38.85136, -84.53592 38.858...
# 2  POLYGON ((-84.54152 39.09927, -84.52563 39.092...
# 3  POLYGON ((-87.14360 37.57777, -87.13882 37.575...
# 4  POLYGON ((-87.15110 37.49865, -87.15485 37.500...

# %%
df.to_file("../data/new/KY_precinct_boundary.geojson", driver='GeoJSON')

# %%
### GENERATE NEIGHBORS
start_time = datetime.datetime()
file = "../data/new/KY_precinct_boundary.geojson"  
df = gp.read_file(file) # open file

#df.rename(columns = {"vtd":"GEOID10"}, inplace = True)
df["neighbors"] = None  # add NEIGHBORS column

for index, row in df.iterrows():
    #what complete
    if index % 1000 == 0:
        print (datetime.datetime.now().strftime("%H:%M:%S"), index)
    # get 'not disjoint' countries
    neighbors = df[~df.geometry.disjoint(row.geometry)].id.tolist()
    # remove own name from the list
    neighbors = [ name for name in neighbors if row.id != name ]
    # add names of neighbors as NEIGHBORS value
    df.at[index, 'neighbors'] = ", ".join(neighbors)

# save GeoDataFrame as a new file
df.to_file("../data/new/KY_neighbors.geojson", driver='GeoJSON')
print ("Finished in ", time.time() - start_time)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f1526dea3378> in <module>
#       1 ### GENERATE NEIGHBORS
# ----> 2 start_time = time.time()
#       3 file = "../data/new/KY_precinct_boundary.geojson"
#       4 df = gp.read_file(file) # open file
#       5
#
# NameError: name 'time' is not defined

# %%
### OVERLAP 

file = "../data/new/KY_precinct_boundary.geojson"
data_temp = gp.read_file(file)

#pltdata_temp=gpd.read_file('data/temp.shp')
#data_temp.head()

# %%
# %matplotlib inline
data_temp.plot(figsize=(12, 12))
#plot.ylim((-80, -65))
#plot. xlim((35, 46))

# %%
data_overlaps = gp.GeoDataFrame(crs = data_temp.crs)
for index, row in data_temp.iterrows():
    #For progress
    if index % 1000 == 0:
        print (datetime.datetime.now().strftime("%H:%M:%S"), index)
    data_temp1 = data_temp.loc[data_temp.id != row.id]
    # check if intersection occured
    overlaps = data_temp1[data_temp1.geometry.overlaps(row.geometry)]['id'].tolist()
    #print ('----Finished overlaps----')
    if len(overlaps) > 0:
        temp_list=[]
        # compare the area with threshold
        for y in overlaps:
            temp_area = gp.overlay(data_temp.loc[data_temp.id == y,],data_temp.loc[data_temp.id == row.id,], how='intersection')
            temp_area = temp_area.loc[temp_area.geometry.area >= 9e-9]
            if temp_area.shape[0]>0:
                #print (index)
                data_overlaps = gp.GeoDataFrame(pd.concat([temp_area,data_overlaps],ignore_index=True),crs=data_temp.crs)
                data_overlaps['sorted'] = data_overlaps.apply(lambda y: sorted([y['id_1'],y['id_2']]),axis=1)
                data_overlaps['sorted'] = data_overlaps.sorted.apply(lambda y: ''.join(y))
                data_overlaps = data_overlaps.drop_duplicates('sorted')
                data_overlaps=data_overlaps.reset_index()[['id_1','id_2','geometry']]
                data_overlaps=gp.GeoDataFrame(pd.concat([temp_area,data_overlaps],ignore_index=True),crs=data_temp.crs)
# get unique of list id
# Out:
# 21:51:28 0
# 21:54:34 1000
# 21:59:29 2000
# 22:06:02 3000

# %%
# %matplotlib inline
ax=data_temp.plot(figsize=(12, 12),alpha=0.7)
data_overlaps.plot(ax=ax,color='red')

# %%
### GAP

data_temp_diss = data_temp[['geometry', 'type']]
data_temp_diss = data_temp.dissolve(by='type')
data_temp_diss = df.drop (columns = ['type', 'id', 'canonical', 'centerX', 'centerY', 'area'])

data_temp_diss.head()
# Out:
#                                            neighbors  \
# 0  21117B121, 21191A101, 21117B120, 21117B101, 21...
# 1  21117B123, 21117B118, 21117B120, 21117B137, 21...
# 2  21037C303, 21117A126, 21117A105, 21015A107, 21...
# 3  21149C102, 21149A101, 21149D101, 21059E101, 21...
# 4  21149C101, 21183A105, 21059E103, 21059E102, 21...
#
#                                             geometry
# 0  POLYGON ((-84.50452 38.79535, -84.50510 38.795...
# 1  POLYGON ((-84.53611 38.85136, -84.53593 38.851...
# 2  POLYGON ((-84.54152 39.09927, -84.54106 39.099...
# 3  POLYGON ((-87.14360 37.57777, -87.13910 37.575...
# 4  POLYGON ((-87.15110 37.49865, -87.15120 37.498...

# %%
interior = data_temp_diss.interiors.values.tolist()

#print (interior)

gap_list = []
for i in interior:
    if i == []:
        continue
    #print(i[0].coords[:])    
    gap_list.append(Polygon(i[0]))
    
data_gaps = gp.GeoDataFrame(geometry = gap_list,crs=data_temp.crs)
data_gaps['feature_touches'] = data_gaps.geometry.apply(lambda y: data_temp.loc[data_temp.touches(y)]['id'].tolist())
data_gaps.tail()
# Out:
#                                             geometry feature_touches
# 5  POLYGON ((-86.87950 37.39321, -86.87938 37.393...     [21183B103]
# 6  POLYGON ((-83.62150 37.98405, -83.62172 37.983...     [21165A101]
# 7  POLYGON ((-84.32168 37.72618, -84.32168 37.725...     [21151B122]
# 8  POLYGON ((-88.08057 37.09020, -88.07996 37.090...     [21143B102]
# 9  POLYGON ((-84.57911 37.62717, -84.57911 37.626...     [21079D103]

# %%
# %matplotlib inline
ax=data_temp.plot(figsize=(12, 12),alpha=0.7)
data_gaps.plot(ax=ax,color='red')
#plot.ylim((-80, -65))
#plot. xlim((35, 46))
