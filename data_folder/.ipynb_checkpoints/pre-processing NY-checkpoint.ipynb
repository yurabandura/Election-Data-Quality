# %%
import geopandas as gp
import csv
import pandas as pd
from shapely.geometry import LineString
import matplotlib.pyplot as plot
import mysql.connector
from shapely.geometry import Polygon, mapping
import datetime

# %%
file = "./NY/ny_p_full_with_neighbors.geojson"    

df = gp.read_file(file)

# %%
#reader = csv.DictReader('../data/NY_county.csv')
reader = csv.reader(open('./NY_county.csv', 'r'))
d = {}
for row in reader:
    #id = row['County FIPS']
    key = row[5]
    value = row[0]
    d[key] = value

# %%
df.head()
# Out:
#     GEOID10   INTPTLAT10    INTPTLON10  \
# 0  36001263  +42.7272097  -073.7873353
# 1  36001232  +42.7295842  -073.7227157
# 2  36001342  +42.7348777  -073.7093285
# 3  36001341  +42.7355901  -073.7037615
# 4  36001277  +42.7313271  -073.8385576
#
#                                            NEIGHBORS  \
# 0  36001262,36001253,36001247,36001252,36001265,3...
# 1  36001243,36001249,36001343,36001344,36001251,3...
# 2  36001233,36001243,36001340,36001341,36001339,3...
# 3                36001233,36001342,36001339,36001285
# 4                         36001275,36001276,36001273
#
#                                             geometry
# 0  MULTIPOLYGON (((-73.79031 42.72261, -73.79346 ...
# 1  MULTIPOLYGON (((-73.71364 42.72799, -73.71245 ...
# 2  MULTIPOLYGON (((-73.71210 42.73705, -73.71187 ...
# 3  MULTIPOLYGON (((-73.70277 42.73421, -73.70336 ...
# 4  MULTIPOLYGON (((-73.82521 42.72768, -73.82575 ...

# %%
#Rename columns
df.rename(columns = {"GEOID10":"id"}, inplace = True)
df.rename(columns = {"INTPTLAT10":"centerX"}, inplace = True)
df.rename(columns = {"INTPTLON10":"centerY"}, inplace = True)
df.rename(columns = {"NEIGHBORS":"neighbors"}, inplace = True)

#Add type columns
df.insert(1, 'canonical', None)
df.insert(2, 'type', 'ORIGINAL') 

#Drop column
#df = df.drop (columns = ['ALAND10'])
df.head()
# Out:
#          id canonical      type      centerX       centerY  \
# 0  36001263      None  ORIGINAL  +42.7272097  -073.7873353
# 1  36001232      None  ORIGINAL  +42.7295842  -073.7227157
# 2  36001342      None  ORIGINAL  +42.7348777  -073.7093285
# 3  36001341      None  ORIGINAL  +42.7355901  -073.7037615
# 4  36001277      None  ORIGINAL  +42.7313271  -073.8385576
#
#                                            neighbors  \
# 0  36001262,36001253,36001247,36001252,36001265,3...
# 1  36001243,36001249,36001343,36001344,36001251,3...
# 2  36001233,36001243,36001340,36001341,36001339,3...
# 3                36001233,36001342,36001339,36001285
# 4                         36001275,36001276,36001273
#
#                                             geometry
# 0  MULTIPOLYGON (((-73.79031 42.72261, -73.79346 ...
# 1  MULTIPOLYGON (((-73.71364 42.72799, -73.71245 ...
# 2  MULTIPOLYGON (((-73.71210 42.73705, -73.71187 ...
# 3  MULTIPOLYGON (((-73.70277 42.73421, -73.70336 ...
# ...

# %%
#Canonical name
state = 'NY'
for i, row in df.iterrows():   
    id = df.at[i, 'id']
    countyId = id[ : 5]
    canonicalId = state + ' ' + d[countyId] + ' ' + id[5:]
    df.at[i, 'canonical'] = canonicalId
    
    #print (canonicalId)
df.head()
# Out:
#          id      canonical      type      centerX       centerY  \
# 0  36001263  NY Albany 263  ORIGINAL  +42.7272097  -073.7873353
# 1  36001232  NY Albany 232  ORIGINAL  +42.7295842  -073.7227157
# 2  36001342  NY Albany 342  ORIGINAL  +42.7348777  -073.7093285
# 3  36001341  NY Albany 341  ORIGINAL  +42.7355901  -073.7037615
# 4  36001277  NY Albany 277  ORIGINAL  +42.7313271  -073.8385576
#
#                                            neighbors  \
# 0  36001262,36001253,36001247,36001252,36001265,3...
# 1  36001243,36001249,36001343,36001344,36001251,3...
# 2  36001233,36001243,36001340,36001341,36001339,3...
# 3                36001233,36001342,36001339,36001285
# 4                         36001275,36001276,36001273
#
#                                             geometry
# 0  MULTIPOLYGON (((-73.79031 42.72261, -73.79346 ...
# 1  MULTIPOLYGON (((-73.71364 42.72799, -73.71245 ...
# 2  MULTIPOLYGON (((-73.71210 42.73705, -73.71187 ...
# ...

# %%
#Replace multipoly with polygon
arr_polygon = [0] * len(df)
arr_polygon = gp.GeoDataFrame (arr_polygon, columns = ['geometry'])
for index, row in df.iterrows():
    #Progress
    if index % 1000 == 0:
        print (index)
    polygon = row.geometry[0]
    arr_polygon.loc[index] = polygon
    
df['geometry'] = arr_polygon
df.head()
# Out:
# 14926
# 14926
#        geometry
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 14921         0
# 14922         0
# 14923         0
# 14924         0
# 14925         0
#
# [14926 rows x 1 columns]
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
#          id      canonical      type      centerX       centerY      area  \
# 0  36001263  NY Albany 263  ORIGINAL  +42.7272097  -073.7873353  0.000231
# 1  36001232  NY Albany 232  ORIGINAL  +42.7295842  -073.7227157  0.000231
# 2  36001342  NY Albany 342  ORIGINAL  +42.7348777  -073.7093285  0.000028
# 3  36001341  NY Albany 341  ORIGINAL  +42.7355901  -073.7037615  0.000025
# 4  36001277  NY Albany 277  ORIGINAL  +42.7313271  -073.8385576  0.000076
#
#                                             geometry
# 0  POLYGON ((42.72261 -73.79031, 42.72022 -73.795...
# 1  POLYGON ((42.72799 -73.71364, 42.72690 -73.709...
# ...

# %%
df.to_file("./NY/NY_precinct_boundary_neighbors_full.geojson", driver='GeoJSON')

# %%
### GENERATE NEIGHBORS

file = "../data/new/NY_precinct_boundary.geojson"  
df = gp.read_file(file) # open file

#df.rename(columns = {"vtd":"GEOID10"}, inplace = True)
df["neighbors"] = None  # add NEIGHBORS column

for index, row in df.iterrows():
    #what complete
    if index % 1000 == 0:
        print (datetime.datetime.now().strftime("%H:%M:%S"), index)
    # get 'not disjoint' countries
    neighbors = df[~df.geometry.disjoint(row.geometry)].id.tolist()
    # remove own name from the list
    neighbors = [ name for name in neighbors if row.id != name ]
    # add names of neighbors as NEIGHBORS value
    df.at[index, 'neighbors'] = ", ".join(neighbors)

# save GeoDataFrame as a new file
df.to_file("../data/new/NY_neighbors.geojson", driver='GeoJSON')
# Out:
# 14:00:54 0
# 14:01:29 1000
# 14:02:04 2000
# 14:02:39 3000
# 14:03:14 4000
# 14:03:49 5000
# 14:04:24 6000
# 14:04:59 7000
# 14:05:34 8000
# 14:06:10 9000
# 14:06:45 10000
# 14:07:20 11000
# 14:07:55 12000
# 14:08:30 13000
# 14:09:05 14000

# %%
### OVERLAP 

file = "../data/new/NY_precinct_boundary.geojson"
data_temp = gp.read_file(file)

#pltdata_temp=gpd.read_file('data/temp.shp')
#data_temp.head()
print ()

# %%
# %matplotlib inline
data_temp.plot(figsize=(12, 12))
#plot.ylim((-80, -65))
#plot. xlim((35, 46))

# %%
#INTERSECTIONS
data_overlaps = gp.GeoDataFrame(crs = data_temp.crs)
for index, row in data_temp.iterrows():
    #For progress
    if index % 1000 == 0:
        print (datetime.datetime.now().strftime("%H:%M:%S"), index)
        
    data_temp1 = data_temp.loc[data_temp.id != row.id]
    # check if intersection occured
    overlaps = data_temp1[data_temp1.geometry.overlaps(row.geometry)]['id'].tolist()
    #print ('----Finished overlaps----')
    if len(overlaps) > 0:
        temp_list=[]
        # compare the area with threshold
        for y in overlaps:
            temp_area = gp.overlay(data_temp.loc[data_temp.id == y,],data_temp.loc[data_temp.id == row.id,], how='intersection')
            temp_area = temp_area.loc[temp_area.geometry.area >= 9e-9]
            if temp_area.shape[0] > 0:
                #print (index)
                data_overlaps = gp.GeoDataFrame(pd.concat([temp_area,data_overlaps],ignore_index=True),crs=data_temp.crs)
                data_overlaps['sorted'] = data_overlaps.apply(lambda y: sorted([y['id_1'],y['id_2']]),axis=1)
                data_overlaps['sorted'] = data_overlaps.sorted.apply(lambda y: ''.join(y))
                data_overlaps = data_overlaps.drop_duplicates('sorted')
                data_overlaps=data_overlaps.reset_index()[['id_1','id_2','geometry']]
                data_overlaps=gp.GeoDataFrame(pd.concat([temp_area,data_overlaps],ignore_index=True),crs=data_temp.crs)
# get unique of list id
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000

# %%
#print (data_overlaps)
overlaps = data_overlaps[['id_1', 'id_2', 'geometry']]
#print (overlaps)
overlaps.to_file("../data/new/NY_overlap.geojson", driver='GeoJSON')

# %%
# %matplotlib inline
ax=data_temp.plot(figsize=(12, 12),alpha=0.7)
overlaps.plot(ax=ax,color='red')

# %%
data_temp_diss = data_temp[['geometry', 'type']]
data_temp_diss = data_temp.dissolve(by='type')
data_temp_diss = df.drop (columns = ['type', 'id', 'canonical', 'centerX', 'centerY', 'area'])

data_temp_diss.head()
# Out:
#                                             geometry  \
# 0  POLYGON ((42.72261 -73.79031, 42.72022 -73.795...
# 1  POLYGON ((42.72799 -73.71364, 42.72690 -73.709...
# 2  POLYGON ((42.73705 -73.71210, 42.73797 -73.711...
# 3  POLYGON ((42.73421 -73.70277, 42.73467 -73.708...
# 4  POLYGON ((42.72768 -73.82521, 42.72768 -73.828...
#
#                                            neighbors
# 0  NY Albany 265, NY Albany 262, NY Albany 253, N...
# 1  NY Albany 346, NY Albany 251, NY Albany 250, N...
# 2  NY Albany 341, NY Albany 346, NY Albany 339, N...
# 3  NY Albany 342, NY Albany 339, NY Albany 233, N...
# 4        NY Albany 276, NY Albany 275, NY Albany 273

# %%
### GAP
interior = data_temp_diss.interiors.values.tolist()

#print (interior)

gap_list = []
for i in interior:
    if i == []:
        continue
    #print(i[0].coords[:])    
    gap_list.append(Polygon(i[0]))
    
data_gaps = gp.GeoDataFrame(geometry = gap_list,crs=data_temp.crs)
data_gaps['feature_touches'] = data_gaps.geometry.apply(lambda y: data_temp.loc[data_temp.touches(y)]['id'].tolist())
data_gaps.head()
# Out:
#                                             geometry feature_touches
# 0  POLYGON ((42.25171 -77.80320, 42.25102 -77.803...        [360032]
# 1  POLYGON ((40.88590 -73.84445, 40.88548 -73.843...      [36005720]
# 2  POLYGON ((40.82317 -73.81041, 40.82144 -73.809...      [36005548]
# 3  POLYGON ((40.85070 -73.78616, 40.85009 -73.785...      [36005606]
# 4  POLYGON ((42.09127 -75.96777, 42.09170 -75.968...      [36007161]

# %%
print (len(data_gaps))
# %matplotlib inline
ax=data_temp.plot(figsize=(12, 12),alpha=0.7)
data_gaps.plot(ax=ax,color='red')
#plot.ylim((-80, -65))
#plot. xlim((35, 46))
# Out:
# 55

# %%
#POPULATE DATABASE
mydb = mysql.connector.connect(
    host="mysql3.cs.stonybrook.edu",
    user='mhaczynska',
    passwd="110670160",
    database = 'mhaczynska'    
)

print (mydb)

# %%
cursor = mydb.cursor()
add_election = ("INSERT INTO mhaczynska.ELECTIONDATA "
               "(REGION, YEAR, TYPE, REPUBLICANVOTES, DEMOCRATICVOTES) "
               "VALUES (%s, %s, %s, %s, %s)")
data_election = ('NY', 2016, 'CONG16', 15, 20)
cursor.execute(add_election, data_election)

mydb.commit()
cursor.close()
mydb.close()
